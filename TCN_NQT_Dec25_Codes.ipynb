# %% [markdown]
# ![WhatsApp Image 2021-12-25 at 11.22.57.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-25 at 11.23.15.jpeg](data:image/jpeg;base64,...)

# %%
s= input ()
count=0
for i in s:
  if i.isdigit()==True:
    if int(i)%2==0:
      count+=1
print (count)

# %% [markdown]
# ---

# %% [markdown]
# ![WhatsApp Image 2021-12-25 at 11.38.00.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-25 at 11.38.15.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-25 at 11.38.28.jpeg](data:image/jpeg;base64,...)

# %%
n=int(input())
lst=[]
count=0
day=0
for i in range(n):
    ele = int(input())
    lst.append(ele)
if n==2:
  print(4)
elif n==3:
  print(12)
elif n!=2:
  for num1 in lst:
    for num2 in lst:
      if num1==num2:
        count+=1
        if count<3:
          day+=1
        elif count<5:
          day+=2
        elif count<7:
          day+=3
        else:
          continue
      else:
        continue
    count=0
  print(day)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5
# 5
