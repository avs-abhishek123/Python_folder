# %%
def adds(a,b):
  if a+b>5:    9>5   7>5
    return a+adds(b-1,a-1)   5+ 3 +
  return a 


x=adds(5,4)
print(x)
# Out:
# 11

# %%
def find_max(nums):
  max_num =float("-inf")
  for num in nums:
    if num>max_num:
      max_num=num

  return max_num

# %%
max_num =float("-inf")

# %%
max_num
# Out:
# -inf

# %%
nums=[2,4,7,23,45,22]
print(find_max(nums))
# Out:
# 45

# %%
a="ahvchsakca"
print(a)
# Out:
# ahvchsakca

# %%
a=265362573
print(a)
# Out:
# 265362573

# %%
a=[1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a=[1,2,3,"shkdgchsdb",5]
print(a)
# Out:
# [1, 2, 3, 'shkdgchsdb', 5]

# %%
a={
   1:"abc",
   2:"ueue",
   "hdhdh": 7
   }
print(a)
# Out:
# {1: 'abc', 2: 'ueue', 'hdhdh': 7}

# %%
a.keys()
# Out:
# dict_keys([1, 2, 'hdhdh'])

# %%
a.values()
# Out:
# dict_values(['abc', 'ueue', 7])

# %%
a.items()
# Out:
# dict_items([(1, 'abc'), (2, 'ueue'), ('hdhdh', 7)])

# %%
def add(a,b):
  lst=[]
  for i in range(a):
    c=a+b
    lst.append(c)
  return lst

# %%
print(add(2,3))
# Out:
# [5, 5]

# %%
print(add(2,3))
# Out:
# 5

# %%
print(add(2,3))
print(add(4,3))
print(add(2,63))
print(add(2,32))
print(add(2,39))
print(add(2,3))
print(add(2,3))
# Out:
# [5, 5]
# [7, 7, 7, 7]
# [65, 65]
# [34, 34]
# [41, 41]
# [5, 5]
# [5, 5]

# %%
a="sreeja"
#  012345

# %%
a[2:]
# Out:
# 'eeja'

# %%
a[:5]
# Out:
# 'sreej'

# %%
a[2:5]
# Out:
# 'eej'

# %%
a[::2]
# Out:
# 'sej'

# %%
a[::-1]
# Out:
# 'ajeers'

# %%
n=len(a)
for i in range(n-1,-1,-1):
  print(a[i], end="")
# Out:
# ajeers

# %%
a=1
b=2
#          temp a b
temp=a    # 1   1 2
a=b       # 1   2 2
b=temp    # 1   2 1


print ("a=",a,"b=",b)
# Out:
# a= 2 b= 1

# %%
a=input()
print(a)
print(type(a))


b=float(a)
print(b)
print(type(b))
# Out:
# 4
# 4
# <class 'str'>
# 4.0
# <class 'float'>

# %%
s="cja@gmail.co.in"
a=s.split("@")
d=a[1].split('.')
#print(a[1])
print(type(d[0]))
#print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.23.54.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.24.04.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.25.13.jpeg](data:image/jpeg;base64,...)

# %%
def mailServer(email):
  s=email
  a=s.split("@")
  d=a[1].split('.')
  x=d[0]
  return x
s="cja@gmail.co.in"
print(mailServer(s))
# Out:
# gmail

# %% [markdown]
# ---

# %% [markdown]
# # Yet to debug the logic, 1 iteration is working rest to do

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.24.24.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.24.33.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-12-22 at 22.25.41.jpeg](data:image/jpeg;base64,...)

# %%
n=6
a=[8,10,15,3,25,4]
r=8
lst=[]
for i in range(1,n):
  for j in range(i):
    ele=abs(a[i]-a[j])
  lst.append(ele)
  print(lst)
ele2=abs(a[n-1]-a[0])
lst.append(ele2)
print(lst)

# %%
n=6
a=[8,10,15,3,25,4]
r=8
def innerlst(n,a):
  lst=[]
  for i in range(1,n-1):
    for j in range(i):
      ele=abs(a[i]-a[j])
    lst.append(ele)
  ele2=abs(a[n-1]-a[0])
  lst.append(ele2)
  return lst
def processData(n,a,r):
  final_lst=[]
  arr=[]
  for i in range(r):
    a=arr
    final_lst=innerlst(n,a)
    arr=final_lst
  return final_lst
print(processData(n,a,r))

# %%
def processData(n,a,r):
  final_lst=[]
  for i in range(r):
    final_lst=innerlst(n,a)
  return final_lst
def innerlst(n,a):
  lst=[]
  for i in range(1,n):
    for j in range(i):
      ele=abs(a[i]-a[j])
    lst.append(ele)
    #print(lst)
  ele2=abs(a[n-1]-a[0])
  lst.append(ele2)
  return lst
print(processData(n,a,r))
# Out:
# [2, 5, 12, 22, 21, 4]
